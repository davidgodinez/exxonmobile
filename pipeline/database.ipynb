# %%
from table_classes import Documents, FormRecognizer
# Out:
# Please enter DataJoint username: root
# Please enter DataJoint password: ········
# [2023-05-24 08:51:41,226][INFO]: Connecting root@localhost:3306
# [2023-05-24 08:51:41,268][INFO]: Connected root@localhost:3306

# %%
FormRecognizer.Metadata & 'is_handwritten=1' & ''
# Out:
# *document_id   *offset    *length    content        polygon    confidence     page_number    is_handwritten
# +------------+ +--------+ +--------+ +------------+ +--------+ +------------+ +------------+ +------------+
# 0              36         7          CR 1.03        =BLOB=     1.0            1              1
# 0              1308       14         Costa Rica Pre =BLOB=     1.0            2              1
# 0              1355       8          CR. 1.03       =BLOB=     1.0            2              1
# 1              245        9          CR. 3. 07      =BLOB=     1.0            1              1
# 1              3788       9          CR. 3. 07      =BLOB=     0.95           4              1
# 1              4014       9          CR. 3. 07      =BLOB=     0.95           5              1
# 1              4239       8          CR. 3.on       =BLOB=     0.95           6              1
# 2              377        8          CR. 3.07       =BLOB=     1.0            2              1
# ...
