# %% [markdown]
# ## Document 1 confusion matrix
#
# | OCR Predictions        | Manual Counts     |
# | ----------- | ----------- |
# | 5      | 4      |
#
# |            | Actual Positive | Actual Negative |
# |------------|-----------------|-----------------|
# | Predicted Positive | 3            | 2            |
# | Predicted Negative | 1            | 134            |
#
#
# #### After filter by confidence level to 0.9 and length of content > 1
#
# |            | Actual Positive | Actual Negative |
# |------------|-----------------|-----------------|
# | Predicted Positive | 3            | 0            |
# | Predicted Negative | 1            | 136            |
#
#
# ---
#
# ## Document 2 confusion matrix
#
# | OCR Predictions        | Manual Counts     |
# | ----------- | ----------- |
# | 13      | 15      |
#
# |            | Actual Positive | Actual Negative |
# |------------|-----------------|-----------------|
# | Predicted Positive | 10            | 3            |
# | Predicted Negative | 2            | 116            |
#
#
# #### After filter by confidence level to 0.9 and length of content > 1
#
# |            | Actual Positive | Actual Negative |
# |------------|-----------------|-----------------|
# | Predicted Positive | 10            | 0            |
# | Predicted Negative | 2            | 119            |
#
#
# ---
#
# ## Document 3 confusion matrix
#
# | OCR Predictions        | Manual Counts     |
# | ----------- | ----------- |
# | 14      | 11      |
#
# |            | Actual Positive | Actual Negative |
# |------------|-----------------|-----------------|
# | Predicted Positive | 7            | 7            |
# | Predicted Negative | 4            | 121            |
#
#
# #### After filter by confidence level to 0.9 and length of content > 1
#
# |            | Actual Positive | Actual Negative |
# |------------|-----------------|-----------------|
# | Predicted Positive | 7            | 0            |
# | Predicted Negative | 4            | 128            |
#
#
# ---
#
# ## Document 4 confusion matrix
#
# | OCR Predictions        | Manual Counts     |
# | ----------- | ----------- |
# | 6      | 4      |
#
# |            | Actual Positive | Actual Negative |
# |------------|-----------------|-----------------|
# | Predicted Positive | 4            | 2            |
# | Predicted Negative | 0            | 60            |
#
#
# #### After filter by confidence level to 0.9 and length of content > 1
#
# |            | Actual Positive | Actual Negative |
# |------------|-----------------|-----------------|
# | Predicted Positive | 4            | 0            |
# | Predicted Negative | 0            | 62            |

# %% [markdown]
# ---
#
# ## Total Confusion Matrix
#
# Out of 34 actual instances of handwriting, form recognizer was able to recognize 24 (71%).
#
#
# |            | Actual Positive | Actual Negative |
# |------------|-----------------|-----------------|
# | Predicted Positive | 24            | 14            |
# | Predicted Negative | 7            | 431            |
#
#
# #### After filter by confidence level to 0.9 and length of content > 1
#
# |            | Actual Positive | Actual Negative |
# |------------|-----------------|-----------------|
# | Predicted Positive | 24            | 0            |
# | Predicted Negative | 7            | 445            |
#
#
# Using our technique we were able to accurately capture 24 of the 34 (71%) handwritten text across 4 documents (20 pages in total) while eliminating false negatives.
